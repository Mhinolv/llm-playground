# %%
import llm
import pandas as pd
from pandas import DataFrame
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
dataPath = '/Users/MarkHinojosa/llm-base/Raw Data/FEEDBACK.csv'

# %%
responseDF = pd.read_csv(dataPath)

# %%
responseDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Unnamed: 0                                            1001 non-null   int64
#  1   Student ID                                            1001 non-null   int64
#  2   Well versed with the subject                          1001 non-null   int64
#  3   Explains concepts in an understandable way            1001 non-null   int64
#  4   Use of presentations                                  1001 non-null   int64
#  5   Degree of difficulty of assignments                   1001 non-null   int64
#  6   Solves doubts willingly                               1001 non-null   int64
#  7   Structuring of the course                             1001 non-null   int64
#  8   Provides support for students going above and beyond  1001 non-null   int64
#  9   Course recommendation based on relevance              1001 non-null   int64
# dtypes: int64(10)
# memory usage: 78.3 KB

# %%
responseDF.head(10)
limitedDF = responseDF.head(10)

# %%
limitedDF
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
# 5           5         832                             7
# 6           6         772                             9
# 7           7         961                             9
# 8           8         814                             6
# 9           9         863                             5
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
# 5                                           2                     7
# 6                                           3                     5
# 7                                           8                     7
# 8                                           5                     8
# 9                                           9                     4
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# 2                                    5                        4
# 3                                    1                        5
# 4                                    4                        6
# 5                                    8                        3
# 6                                    2                       10
# 7                                    4                        4
# 8                                    6                        4
# 9                                    7                        9
#
#    Structuring of the course  \
# 0                          2
# 1                          1
# 2                          2
# 3                          9
# 4                          6
# 5                          5
# 6                          3
# 7                          3
# 8                          4
# 9                          4
#
#    Provides support for students going above and beyond  \
# 0                                                  1
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  9
# 5                                                  1
# 6                                                  8
# 7                                                  3
# 8                                                  7
# 9                                                  4
#
#    Course recommendation based on relevance
# 0                                         8
# 1                                         9
# 2                                         1
# 3                                         6
# 4                                         9
# 5                                         4
# 6                                         1
# 7                                        10
# 8                                         9
# 9                                         5

# %%
model = llm.get_model("wizardlm-13b-v1")

# %%
response = model.prompt(f"Can you create high level summary of the data within the column: Course recommendation based on relevance, in this data - {responseDF}",
                        system="Answer like a Sr. Data Analyst")
print(response.text())
# Out:
# The data provided is a table with various attributes related to courses and their relevance. The first column, "Course recommendation based on relevance", indicates the recommended course for each student based on its relevance to them. This can be summarized as follows:
#
# - Course recommendations are mostly 8 or 9 (out of 10), indicating a high level of relevance and suitability for most students.
# - The highest recommendation is 9, which corresponds to the first row in the table.
# - There are no rows with a recommendation score of 1 or 2, suggesting that these courses may not be as relevant or suitable for most students.
#
# The other columns provide additional information about each course:
#
# - "Explains concepts in an understandable way" and "Solves doubts willingly": These two attributes indicate the quality of teaching and support provided by the instructors, with higher scores suggesting better performance in these areas.
# - "Degree of difficulty of assignments": This attribute reflects the complexity level of the coursework assigned to students, with higher scores indicating more challenging tasks.
# - "Structuring of the course" and "Provides support for students going above and beyond": These attributes evaluate the organization and effectiveness of the course structure as well as the instructor's willingness to provide additional assistance outside of regular class hours. Higher scores in these areas suggest a more structured, supportive learning environment.
#
# Overall, this data suggests that most courses have high relevance for students based on their performance in various aspects such as teaching quality, course difficulty, and level of support provided by the instructors. However, there may be some courses with lower scores in these areas, indicating a less suitable or relevant learning experience for many students.
